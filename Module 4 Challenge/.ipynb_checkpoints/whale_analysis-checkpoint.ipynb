# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whalepath = Path("Resources/whale_returns.csv")
#reading it in with index as date, I think this does something
whale_df = pd.read_csv(whalepath, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
# Count nulls
whale_df.isnull()
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algopath = Path("Resources/algo_returns.csv")
#reading it in with index as date, I think this does something
algo_df = pd.read_csv(algopath, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
# Count nulls
algo_df.isnull()
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
SP500path = Path("Resources/sp500_history.csv")
#if I try to read this with date as index it causes major problems, There also is a mjor problem with this I cannot fix. If error, run first line of code and go down and it should fix, I am not sure why.
SP500_df = pd.read_csv(SP500path)

# %%
# Check Data Types
print(SP500_df.dtypes)
#had problems using string replace to get rid of $ sign.
SP500_df.describe
# Out:
# Date     object
# Close    object
# dtype: object
# <bound method NDFrame.describe of            Date     Close
# 0     23-Apr-19  $2933.68
# 1     22-Apr-19  $2907.97
# 2     18-Apr-19  $2905.03
# 3     17-Apr-19  $2900.45
# 4     16-Apr-19  $2907.06
# ...         ...       ...
# 1644   5-Oct-12  $1460.93
# 1645   4-Oct-12  $1461.40
# 1646   3-Oct-12  $1450.99
# 1647   2-Oct-12  $1445.75
# 1648   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]>

# %%
# Fix Data Types
SP500_df["Close"] = SP500_df["Close"].astype(str)
SP500_df["Close"] = SP500_df["Close"].str.replace("$", "").astype(float)
SP500_df.columns
SP500_df.index = pd.to_datetime(SP500_df.index)
# Out:
# C:\Users\hsiao\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Calculate Daily Returns
#index date
SP500_df.set_index(pd.to_datetime(SP500_df['Date'], infer_datetime_format=True), inplace=True)

#gets rid of other date column
SP500_df.drop(columns=['Date'], inplace=True)

#dataframe is now pct change like the rest of the dataframes
SP500_df = SP500_df.pct_change()
SP500_df.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
SP500_df.isnull()
SP500_df.isnull().sum()
SP500_df.dropna()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
SP500_df = SP500_df.rename(columns={"Close": "SP500"})

SP500_df.head()
# Out:
#                SP500
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, SP500_df], axis="columns", join="inner")
combined_df.sort_index(inplace=True)


combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2     SP500
# Date
# 2015-03-02  0.003200  0.004559
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.columns
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2', 'SP500'],
#       dtype='object')

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
#want to review how cumprod works
cumulative_returns = (1 + daily_returns).cumprod() - 1
cumulative_returns

# Plot cumulative returns
cumulative_returns.plot(figsize=(10,5), title="Cumulative Returns of All portfolios over the Last 10 Years")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of All portfolios over the Last 10 Years'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
#how do i make these boxplots more readable?
whale_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
algo_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
SP500_df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
#create STD dataframes
whale_std_df = whale_df.std()
algo_std_df = algo_df.std()
SP500_std_df = SP500_df.std()


whale_std_df.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
algo_std_df.head()
# Out:
# Algo 1    0.007972
# Algo 2    0.008466
# dtype: float64

# %%
SP500_std_df.head()
# Out:
# SP500    0.008135
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
SP500_std_df.head()
# Determine which portfolios are riskier than the S&P 500
#the higher the standard deviation, the higher the risk.

#ANSWER

#/SP500    0.008135 > /TIGER GLOBAL MANAGEMENT LLC  0.010824 /BERKSHIRE HATHAWAY INC  0.012831 /Algo 2    0.008466

#ANSWER
# Out:
# SP500    0.008135
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized = SP500_std_df * np.sqrt(252)
annualized.head()
# Out:
# SP500    0.129133
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
SP500_df.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
algo_df.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
whale_df.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
#import seasborn library
import seaborn as sns
price_correlation = combined_df.corr()
# Display de correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio and SP500

covariance = combined_df['Algo 1'].cov(combined_df['SP500'])
covariance

# Calculate variance of S&P 500
variance = SP500_df.var()
variance


# Computing beta

SP500_beta = covariance / variance
SP500_beta

# Plot beta trend
rolling_covariance = combined_df['Algo 1'].rolling(window=30).cov(combined_df['SP500'])
rolling_variance = combined_df['SP500'].rolling(window=30).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta of SP500')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of SP500'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))

sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.360829
# Algo 2                         0.506929
# SP500                         -0.510171
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_ratios.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %%
##########ANSWER############ANSWER##################################

#Algo 1 did better than all other portfolios

#algo 2 did better than all portfolios except MR Warren Buffet's.

##########ANSWER############ANSWER##################################

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
#I will be using the three csv files given to me in the resources /aapl_historical/ /cost_historical/  /goog_historical/
#set the date as index 
#drop the date column
#drop the symbol column
# Reorganize portfolio data by having a column per symbol
#rename columns the symbol

# %%
# Reading data from 1st stock
aaplpath = Path("Resources/aapl_historical.csv")
aapl_df = pd.read_csv(aaplpath, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

aapl_df.drop(columns=['Symbol'], inplace=True)
aapl_df = aapl_df.rename(columns={"NOCP": "AAPL"})

aapl_df.head()
# Out:
#               AAPL
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86
# 2019-05-06  208.48
# 2019-05-03  211.75

# %%
# Reading data from 2nd stock
costpath = Path("Resources/cost_historical.csv")
cost_df = pd.read_csv(costpath, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

cost_df.drop(columns=['Symbol'], inplace=True)
cost_df = cost_df.rename(columns={"NOCP": "COST"})
cost_df.head()
# Out:
#               COST
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62

# %%
# Reading data from 3rd stock
googpath = Path("Resources/goog_historical.csv")
goog_df = pd.read_csv(googpath, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

goog_df.drop(columns=['Symbol'], inplace=True)
goog_df = goog_df.rename(columns={"NOCP": "GOOG"})
goog_df.head()
# Out:
#                GOOG
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10
# 2019-05-06  1189.39
# 2019-05-03  1185.40

# %%
# Combine all stocks in a single DataFrame
port1_df = pd.concat([aapl_df, cost_df, goog_df], axis="columns", join="inner")
port1_df.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2019-05-09  200.72  243.47  1162.38
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-03  211.75  244.62  1185.40

# %%
# Calculate daily returns
port1_df = port1_df.pct_change()

# Drop NAs
port1_df.isnull()
port1_df.isnull().sum()
port1_df.dropna()


# Display sample data
port1_df.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2019-05-09       NaN       NaN       NaN
# 2019-05-08  0.010861 -0.008749  0.003347
# 2019-05-07 -0.000197 -0.004806  0.006714
# 2019-05-06  0.027704  0.016862  0.013023
# 2019-05-03  0.015685  0.001597 -0.003355

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
port1_return_df = port1_df.mul(weights, axis=1).sum(axis=1)



# Display sample data
port1_return_df
# Out:
# Trade DATE
# 2019-05-09    0.000000
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
#                 ...
# 2018-05-17    0.006112
# 2018-05-16    0.001618
# 2018-05-15   -0.009283
# 2018-05-14    0.010216
# 2018-05-11   -0.000012
# Length: 250, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
return_df = pd.concat([combined_df, port1_return_df], axis="columns", join="inner")

return_df.head()
return_df.columns
return_df = return_df.rename(columns={0: 'Port1'})

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

return_df.isnull()
return_df.isnull().sum()
return_df.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
return_df.rolling(window=21).std().plot(figsize=(10,5))

# Plot rolling standard deviation
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
price_correlation = return_df.corr()
# Display de correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
covariance = return_df['Port1'].cov(return_df['SP500'])
covariance

# Calculate variance of S&P 500
variance = SP500_df.var()
variance


# Computing beta

SP500_beta = covariance / variance
SP500_beta

# Plot beta trend
rolling_covariance =return_df['Port1'].rolling(window=60).cov(return_df['SP500'])
rolling_variance = return_df['SP500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of SP500')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of SP500'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios = (return_df.mean() * 252) / (return_df.std() * np.sqrt(252))

sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.395449
# PAULSON & CO.INC.              0.267115
# TIGER GLOBAL MANAGEMENT LLC   -1.019946
# BERKSHIRE HATHAWAY INC         0.141691
# Algo 1                         2.034208
# Algo 2                         0.082577
# SP500                         -0.432942
# Port1                         -0.614330
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
#it seems my portfolio did worse than everyone except Tiger.
#I am not sure if I understand sharpe ratios yet because I got different results. are sharpe ratios dependent on what you compare them too? not sure...
